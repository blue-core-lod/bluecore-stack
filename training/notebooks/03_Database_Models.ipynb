# %%
import os

from bluecore_models.models import Instance, ResourceBase, Version, Work, Hub
from sqlalchemy import create_engine, func, select
from sqlalchemy.orm import Session

BC_POSTGRES_DB = os.environ.get("DATABASE", "postgresql+psycopg2://airflow:airflow@postgres:5432/bluecore")
